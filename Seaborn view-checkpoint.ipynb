# %%
import pandas as pd
import numpy as np
import seaborn as sn

# %%
df =pd.read_csv('Pokemon.csv')
df
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# ...

# %%
from matplotlib import pyplot as plt
def sinplot(flip=1):
    x=np.linspace(5,20,100)
    for i in range (1,10):
        plt.plot(x,np.sin(x+i*.5)*(7-i)*flip)
sb.set_style('whitegrid',{'axes.axisbelow': True})
set()
sinplot()
sb.despine()
plt.show()

# %%
import seaborn as sb
print (sb.axes_style())
# Out:
# {'axes.facecolor': 'white', 'axes.edgecolor': '.8', 'axes.grid': True, 'axes.axisbelow': True, 'axes.labelcolor': '.15', 'figure.facecolor': 'white', 'grid.color': '.8', 'grid.linestyle': '-', 'text.color': '.15', 'xtick.color': '.15', 'ytick.color': '.15', 'xtick.direction': 'out', 'ytick.direction': 'out', 'lines.solid_capstyle': 'round', 'patch.edgecolor': 'w', 'patch.force_edgecolor': True, 'image.cmap': 'rocket', 'font.family': ['sans-serif'], 'font.sans-serif': ['Arial', 'DejaVu Sans', 'Liberation Sans', 'Bitstream Vera Sans', 'sans-serif'], 'xtick.bottom': False, 'xtick.top': False, 'ytick.left': False, 'ytick.right': False, 'axes.spines.left': True, 'axes.spines.bottom': True, 'axes.spines.right': True, 'axes.spines.top': True}

# %%
# Quantative color palette.
import seaborn as sb
from matplotlib import pyplot as plt
current_palette=sb.color_palette() #(palette=None,n_colors=None,desat=None)
sb.palplot(current_palette)
plt.show()

# %%
#Sequential color palette. We add 's' to color character passed in palplot.
import seaborn as sb
from matplotlib import pyplot as plt
current_palette=sb.color_palette() #(palette=None,n_colors=None,desat=None)
sb.palplot(sb.color_palette('Blues'))
plt.show()

# %%
import seaborn as sb
from matplotlib import pyplot as plt
current_palette=sb.color_palette() #(palette=None,n_colors=None,desat=None)
sb.palplot(sb.color_palette('BrBG',7))
plt.show()

# %%
def sinplot(flip=1):
    x=np.linspace(2,20,100)
    for i in range (1,10):
        plt.plot(x,np.sin(x+i*.5)*(7-i)*flip)
sb.set_style('whitegrid',{'axes.axisbelow': True})
#set()
sb.set_palette('husl')
#sb.displot()#mostly used with histogram plotting.
sinplot()
#sb.despine()
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sb
sb.displot(df['Total'],kde=False)
plt.show()

# %% [markdown]
# # Kernal Distribution Estimates(KDE)

# %%
#We set kde to True to get the curve.
from matplotlib import pyplot as plt
import seaborn as sb
sb.displot(df['Total'],kde=True)
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sb
sb.displot(df['Total'])
plt.show()

# %%
sb.jointplot(x='Total',y='Defense',data=df)
plt.show()

# %%
#hexbin plot. Used to plot data that is too scattered hence can not be analyzed in scatter plot.
sb.jointplot(x='Total',y='Defense',data=df,kind='hex')
plt.show()

# %%
#use of kde on kind function to plot the data. kind takes=(scatter,kde,hist,hex,reg,resid)
sb.jointplot(x='Total',y='Stage',data=df,kind='kde')
plt.show()

# %%
sb.set_style('white')
sb.pairplot(df)
plt.show()
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sb.set_style('white')
sb.pairplot(df,palette='husl',kind='scatter',diag_kind='kde')
plt.show()

# %%
#Analyzing categorical data. We use stripplot() and swarmplot()
sb.stripplot(x='Attack',y='Speed',data=df,jitter=True)
plt.show()

# %%
sb.swarmplot(x='Type 1',y='Defense',data=df)
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
dft=pd.read_csv('Salary_Data.csv')
dft.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
#sb.stripplot(x='YearsExperience',y='Salary',data=dft,jitter=True)
sb.swarmplot(x='YearsExperience',y='Salary',data=dft)
plt.show()

# %%
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
df.shape
# Out:
# (151, 13)

# %%
# Distribution of observation. Used to provide more instant in visualizing data for easier understanding.
sb.boxplot(x='Type 1',y='Defense',data=df)
plt.show()

# %%
# Combination of density and kernal density estimates. It contains box plots in the inside.
sb.violinplot(x='Type 1',y='Stage',data=df)
plt.show()
#sb.violinplot(x='Type 1',y='Defense',hue='Type 2',data=df)
#plt.show()
# The wider section on violin plot shows region of higher desity while narrow region shows region of low density.
# Interquartile range is show inside the boxplot

# %%
import seaborn as sb
sb.set_style('dark')
set()
sb.displot(x='Sp. Atk',y='Sp. Def',data=df,kind='kde')
plt.show()

# %%
import seaborn as sb
sb.barplot(x='Type 2',y='Defense',data=df)#hue='Speed'
plt.show()

# %%
df=pd.read_csv('tracking2020.csv')
df.head()
# Out:
#                       time      x      y     s     a   dis       o     dir  \
# 0  2021-01-03T18:03:02.200  61.21  46.77  0.08  0.13  0.01  186.21  144.73
# 1  2021-01-03T18:03:02.300  61.22  46.77  0.11  0.19  0.01  184.87  126.09
# 2  2021-01-03T18:03:02.400  61.23  46.76  0.10  0.18  0.01  183.38  108.95
# 3  2021-01-03T18:03:02.500  61.24  46.76  0.11  0.22  0.01  180.24   91.57
# 4  2021-01-03T18:03:02.600  61.25  46.76  0.05  0.20  0.01  172.44  119.91
#
#   event    nflId   displayName  jerseyNumber position  team  frameId  \
# 0  None  42901.0  Dean Marlowe          31.0       SS  home        1
# 1  None  42901.0  Dean Marlowe          31.0       SS  home        2
# 2  None  42901.0  Dean Marlowe          31.0       SS  home        3
# 3  None  42901.0  Dean Marlowe          31.0       SS  home        4
# 4  None  42901.0  Dean Marlowe          31.0       SS  home        5
#
#        gameId  playId playDirection
# 0  2021010300      40          left
# ...

# %%
df.shape
# Out:
# (11821701, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11821701 entries, 0 to 11821700
# Data columns (total 18 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   time           object
#  1   x              float64
#  2   y              float64
#  3   s              float64
#  4   a              float64
#  5   dis            float64
#  6   o              float64
#  7   dir            float64
#  8   event          object
#  9   nflId          float64
#  10  displayName    object
#  11  jerseyNumber   float64
#  12  position       object
#  13  team           object
#  14  frameId        int64
#  15  gameId         int64
#  16  playId         int64
#  17  playDirection  object
# dtypes: float64(9), int64(3), object(6)
# memory usage: 1.6+ GB

# %%
df.duplicated()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 11821696    False
# 11821697    False
# 11821698    False
# 11821699    False
# 11821700    False
# Length: 11821701, dtype: bool

# %%
df.drop(columns=['position','playDirection','team'],axis=0,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-214-969a4f153607> in <module>
# ----> 1 df.drop(columns=['position','playDirection','team'],axis=0,inplace=True)
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df.head()
# Out:
#                       time      x      y     s     a   dis       o     dir  \
# 0  2021-01-03T18:03:02.200  61.21  46.77  0.08  0.13  0.01  186.21  144.73
# 1  2021-01-03T18:03:02.300  61.22  46.77  0.11  0.19  0.01  184.87  126.09
# 2  2021-01-03T18:03:02.400  61.23  46.76  0.10  0.18  0.01  183.38  108.95
# 3  2021-01-03T18:03:02.500  61.24  46.76  0.11  0.22  0.01  180.24   91.57
# 4  2021-01-03T18:03:02.600  61.25  46.76  0.05  0.20  0.01  172.44  119.91
#
#   event    nflId   displayName  jerseyNumber  frameId      gameId  playId
# 0  None  42901.0  Dean Marlowe          31.0        1  2021010300      40
# 1  None  42901.0  Dean Marlowe          31.0        2  2021010300      40
# 2  None  42901.0  Dean Marlowe          31.0        3  2021010300      40
# 3  None  42901.0  Dean Marlowe          31.0        4  2021010300      40
# 4  None  42901.0  Dean Marlowe          31.0        5  2021010300      40

# %%
import seaborn as sb
sb.barplot(x='Stage',y='Speed',data=df)#hue='Speed'
plt.show()

# %%
import seaborn as sb
sb.countplot(x='Type 2',y='Defense',data=df)#hue='Speed'
plt.show()

# %%
df=pd.read_csv('Pokemon.csv')
df
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# ...

# %%
import seaborn as sb
from matplotlib import pyplot as plt
sb.countplot(x='Defense',data=df,palette='Blues')#hue='Speed'
plt.show()

# %%
#pointplot serves same purpose as barplot but values are represented by estimate points on the graph.
sb.pointplot(x='Attack',y='Speed',hue='Stage',data=df)
plt.show()

# %%
sb.boxplot(data=df,orient='h')
plt.show()

# %%
sb.catplot(x='Speed',y='Attack',hue='Stage',data=df)
plt.show()

# %%
sb.catplot(x="Type 1", y="Speed", hue="Stage", kind='violin',data=df);
plt.show()

# %%
#catplot used to plot multiple grids with same data for easy visibility. values passed depend on col( values.)
sb.catplot(x="Type 1", y="Attack", kind='violin',col='Stage',data=df);
plt.show()

# %%
sb.catplot("Defense", col="Stage", 
col_wrap=3,data=df[df.Defense.notnull()],kind="count")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Used to represent linear relationship functions.
sb.regplot(x='Defense',y='Attack',data=df)
plt.show()

# %%
sb.lmplot(x='Defense',y='Attack',data=df)
plt.show()

# %%
sb.lmplot(x="Defense", y="Attack", data=df)
plt.show()

# %%
sb.set_style('whitegrid')
sb.lmplot(x="Defense", y="Attack", data=df,order=2)
plt.show()

# %%
#Initializing the facetgrid nothing is drawn
sb.FacetGrid(df,col='Stage')
plt.show()

# %%
x=sb.FacetGrid(df,col='Stage')
x.map(plt.hist,'Stage')
plt.show()

# %%
g = sb.PairGrid(df)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter);
plt.show()
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\numpy\lib\histograms.py in _unsigned_subtract(a, b)
#     350     try:
# --> 351         dt = signed_to_unsigned[dt.type]
#     352     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-293-b92db004a2a0> in <module>
#       1 g = sb.PairGrid(df)
# ----> 2 g.map_diag(plt.hist)
#       3 g.map_offdiag(plt.scatter);
#       4 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
#    1372
#    1373         if "hue" not in signature(func).parameters:
# ...

# %%
g = sb.PairGrid(df)
g.map_upper(plt.scatter)
g.map_lower(sb.kdeplot, cmap="Blues_d")
g.map_diag(sb.kdeplot, lw=3, legend=False);
plt.show()

# %%
import numpy as np
import seaborn as sb
#x=np.random.randn(69,113)
sb.distplot(x=np.random.randn(2233),kde=False,color='Red',fit=None)
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import seaborn as sb
#x=np.random.randn(69,113)
sb.jointplot(x=np.random.randn(2233),y=np.random.randn(2233),color='Red',kind='scatter')

# %%
import seaborn as sb
import numpy as np
from matplotlib import pyplot as plt
df=pd.read_csv('Pokemon.csv')
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
sb.catplot(x='Attack',y='Defense',kind='boxen',data=df,hue='Stage',dodge=False)

# %%
sb.relplot(x='Name',y='Defense',kind='line',hue='Type 1',style='Stage',data=df,col_wrap=None)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0, flags=flags)
