# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df_covid=pd.read_csv("covid data.csv")
df_covid.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# 3  11/12/2020   11     12  2020     63      10             Afghanistan    AF
# 4  10/12/2020   10     12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# ...

# %%
df_covid.shape
# Out:
# (61900, 12)

# %%
df_covid.describe().T
# Out:
#                                                       count          mean  \
# day                                                 61900.0  1.562893e+01
# month                                               61900.0  7.067157e+00
# year                                                61900.0  2.019999e+03
# cases                                               61900.0  1.155147e+03
# deaths                                              61900.0  2.605546e+01
# popData2019                                         61777.0  4.098770e+07
# Cumulative_number_for_14_days_of_COVID-19_cases...  59021.0  6.632059e+01
#
#                                                              std          min  \
# day                                                 8.841582e+00     1.000000
# month                                               2.954776e+00     1.000000
# year                                                3.288217e-02  2019.000000
# ...

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61900 entries, 0 to 61899
# Data columns (total 12 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   dateRep                                                     61900 non-null  object
#  1   day                                                         61900 non-null  int64
#  2   month                                                       61900 non-null  int64
#  3   year                                                        61900 non-null  int64
#  4   cases                                                       61900 non-null  int64
#  5   deaths                                                      61900 non-null  int64
#  6   countriesAndTerritories                                     61900 non-null  object
# ...

# %%
df_covid.isnull().sum()
# Out:
# dateRep                                                          0
# day                                                              0
# month                                                            0
# year                                                             0
# cases                                                            0
# deaths                                                           0
# countriesAndTerritories                                          0
# geoId                                                          275
# countryterritoryCode                                           123
# popData2019                                                    123
# continentExp                                                     0
# Cumulative_number_for_14_days_of_COVID-19_cases_per_100000    2879
# dtype: int64

# %%
df_covid.drop(['dateRep','year','countriesAndTerritories','geoId','countryterritoryCode'],axis=1,inplace=True)

# %%
df_covid
# Out:
#        day  month  cases  deaths  popData2019 continentExp  \
# 0       14     12    746       6   38041757.0         Asia
# 1       13     12    298       9   38041757.0         Asia
# 2       12     12    113      11   38041757.0         Asia
# 3       11     12     63      10   38041757.0         Asia
# 4       10     12    202      16   38041757.0         Asia
# ...    ...    ...    ...     ...          ...          ...
# 61895   25      3      0       0   14645473.0       Africa
# 61896   24      3      0       1   14645473.0       Africa
# 61897   23      3      0       0   14645473.0       Africa
# 61898   22      3      1       0   14645473.0       Africa
# 61899   21      3      1       0   14645473.0       Africa
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                               9.013779
# 1                                               7.052776
# 2                                               6.868768
# ...

# %%
continetE_num={'Asia':0,'Europe':1,'Africa':2,'Oceania':3,'America':4}
df_covid['continetE_num']=df_covid['continentExp'].map(continetE_num)

# %%
df_covid
# Out:
#        day  month  cases  deaths  popData2019  continentExp  \
# 0       14     12    746       6   38041757.0           NaN
# 1       13     12    298       9   38041757.0           NaN
# 2       12     12    113      11   38041757.0           NaN
# 3       11     12     63      10   38041757.0           NaN
# 4       10     12    202      16   38041757.0           NaN
# ...    ...    ...    ...     ...          ...           ...
# 61895   25      3      0       0   14645473.0           NaN
# 61896   24      3      0       1   14645473.0           NaN
# 61897   23      3      0       0   14645473.0           NaN
# 61898   22      3      1       0   14645473.0           NaN
# 61899   21      3      1       0   14645473.0           NaN
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  \
# 0                                               9.013779
# 1                                               7.052776
# 2                                               6.868768
# ...

# %%
df_covid.iloc[338:500,10]
# Out:
# 338      Asia
# 339      Asia
# 340    Europe
# 341    Europe
# 342    Europe
#         ...
# 495    Europe
# 496    Europe
# 497    Europe
# 498    Europe
# 499    Europe
# Name: continentExp, Length: 162, dtype: object
